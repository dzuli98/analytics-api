# %%
import requests

# %%
path = '/api/events'
base_url = 'http://localhost:8000'
endpoint = f'{base_url}{path}'

# %%
response = requests.get(endpoint)
if response.ok:
    print("API is reachable.")
    data = response.json()
    print("Response JSON:", data, type(data))
# Out:
# API is reachable.
# Response JSON: {'items': [1, 2, 3]} <class 'dict'>
