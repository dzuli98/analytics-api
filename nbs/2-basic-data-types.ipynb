# %%
import requests

# %%
path = '/api/events/10'
base_url = 'http://localhost:8000'
endpoint = f'{base_url}{path}'

# %%
response = requests.get(endpoint)
if response.ok:
    print("API is reachable.")
    data = response.json()
    print("Response JSON:", data, type(data))

# %%
data = {'page': 'test+'}

# %%
import json
type(json.dumps(data))
json.dumps(data)
# Out:
# '{"page": "test+"}'

# %%
headers = {
    'Content-Type': 'application/json'
}

create_endpoint = f'{base_url}/api/events'
response = requests.post(create_endpoint, json={'page':'test+'}, headers=headers)
print(response.headers)
print(response.ok)
if response.ok:
    print(response.json())
else:
    print(response.text)
# Out:
# {'date': 'Fri, 16 Jan 2026 11:14:20 GMT', 'server': 'uvicorn', 'content-length': '40', 'content-type': 'application/json'}
# True
# {'page': 'test+', 'id': 5, 'description': ''}

# %%
headers = {
    'Content-Type': 'application/json'
}

update_endpoint = f'{base_url}/api/events/2'
response = requests.put(update_endpoint, json={'description': 'NEW!'}, headers=headers)
print(response.headers)
print(response.ok)
if response.ok:
    print(response.json())
else:
    print(response.text)
# Out:
# {'date': 'Fri, 16 Jan 2026 12:16:00 GMT', 'server': 'uvicorn', 'content-length': '40', 'content-type': 'application/json'}
# True
# {'description': '', 'id': 2, 'page': 'test+'}

# %%
from pprint import pprint

# %%
path = '/api/events/10'
base_url = 'http://localhost:8000'
endpoint = f'{base_url}{path}'
response = requests.get(endpoint)
if response.ok:
    pprint(response.json())
else:
    print("Status:", response.status_code)
    print("Error:", response.text)
# Out:
# Status: 404
# Error: {"detail":"Event with 10 does not exit!"}
