# %%
import requests

# %%
path = '/api/events/10'
base_url = 'http://localhost:8000'
endpoint = f'{base_url}{path}'

# %%
response = requests.get(endpoint)
if response.ok:
    print("API is reachable.")
    data = response.json()
    print("Response JSON:", data, type(data))

# %%
data = {'page': 'test+'}

# %%
import json
type(json.dumps(data))
json.dumps(data)
# Out:
# '{"page": "test+"}'

# %%
headers = {
    'Content-Type': 'application/json'
}

create_endpoint = f'{base_url}/api/events'
response = requests.post(create_endpoint, json={'page':'test+'}, headers=headers)
print(response.headers)
print(response.ok)
if response.ok:
    print(response.json())
else:
    print(response.text)
# Out:
# {'date': 'Fri, 16 Jan 2026 12:38:35 GMT', 'server': 'uvicorn', 'content-length': '126', 'content-type': 'application/json'}
# True
# {'id': 6, 'description': '', 'updated_at': '2026-01-16T12:38:35.639768Z', 'created_at': '2026-01-16T12:38:35.639754Z', 'page': 'test+'}

# %%
headers = {
    'Content-Type': 'application/json'
}

update_endpoint = f'{base_url}/api/events/2'
response = requests.put(update_endpoint, json={'description': 'NEW!'}, headers=headers)
print(response.headers)
print(response.ok)
if response.ok:
    print(response.json())
else:
    print(response.text)
# Out:
# {'date': 'Fri, 16 Jan 2026 12:38:47 GMT', 'server': 'uvicorn', 'content-length': '130', 'content-type': 'application/json'}
# True
# {'id': 2, 'description': 'NEW!', 'updated_at': '2026-01-16T12:38:47.978551Z', 'created_at': '2026-01-16T12:38:33.691482Z', 'page': 'test+'}

# %%
from pprint import pprint

# %%
path = '/api/events/10'
base_url = 'http://localhost:8000'
endpoint = f'{base_url}{path}'
response = requests.get(endpoint)
if response.ok:
    pprint(response.json())
else:
    print("Status:", response.status_code)
    print("Error:", response.text)
# Out:
# Status: 404
# Error: {"detail":"Event with 10 does not exit!"}

# %%
import random  
event_count = 1000

pages = ['/about', '/contact', '/pages', '/pricing']

for i in range(event_count):
    page = random.choice(pages)
    response = requests.post(create_endpoint, json={'page': page})
    if response.ok:
        data = response.json()
        print(f"Created event {data['id']} for page {data['page']}")
    else:
        print("Error:", response.text)
# Out:
# Created event 1 for page /about
# Created event 2 for page /pricing
# Created event 3 for page /pages
# Created event 4 for page /contact
# Created event 5 for page /pages
# Created event 6 for page /about
# Created event 7 for page /contact
# Created event 8 for page /pricing
# Created event 9 for page /pricing
# Created event 10 for page /contact
# Created event 11 for page /about
# Created event 12 for page /pricing
# Created event 13 for page /about
# Created event 14 for page /about
# Created event 15 for page /pricing
# Created event 16 for page /pricing
# Created event 17 for page /pages
# Created event 18 for page /about
# Created event 19 for page /contact
# Created event 20 for page /pages
# Created event 21 for page /contact
# Created event 22 for page /pages
# Created event 23 for page /contact
# Created event 24 for page /pricing
# Created event 25 for page /pages
# Created event 26 for page /pricing
# Created event 27 for page /pages
# Created event 28 for page /about
# Created event 29 for page /pricing
# Created event 30 for page /contact
# Created event 31 for page /pages
# Created event 32 for page /pages
# Created event 33 for page /about
# Created event 34 for page /pricing
# Created event 35 for page /pages
# Created event 36 for page /contact
# Created event 37 for page /pages
# Created event 38 for page /pages
# Created event 39 for page /contact
# Created event 40 for page /pricing
# Created event 41 for page /about
# Created event 42 for page /about
# Created event 43 for page /pricing
# Created event 44 for page /pages
# Created event 45 for page /about
# Created event 46 for page /pages
# Created event 47 for page /pages
# Created event 48 for page /pricing
# Created event 49 for page /pricing
# Created event 50 for page /pages
# Created event 51 for page /pricing
# Created event 52 for page /pricing
# Created event 53 for page /contact
# Created event 54 for page /contact
# Created event 55 for page /pricing
# Created event 56 for page /about
# Created event 57 for page /contact
# Created event 58 for page /contact
# Created event 59 for page /about
# Created event 60 for page /pages
# Created event 61 for page /pages
# Created event 62 for page /pricing
# Created event 63 for page /pricing
# Created event 64 for page /contact
# Created event 65 for page /pricing
# Created event 66 for page /contact
# Created event 67 for page /about
# Created event 68 for page /pages
# Created event 69 for page /about
# Created event 70 for page /about
# Created event 71 for page /about
# Created event 72 for page /pricing
# Created event 73 for page /pages
# Created event 74 for page /pages
# Created event 75 for page /pricing
# Created event 76 for page /pricing
# Created event 77 for page /pages
# Created event 78 for page /about
# Created event 79 for page /pages
# Created event 80 for page /pricing
# Created event 81 for page /about
# Created event 82 for page /pricing
# Created event 83 for page /contact
# Created event 84 for page /pages
# Created event 85 for page /contact
# Created event 86 for page /pages
# Created event 87 for page /pages
# Created event 88 for page /about
# Created event 89 for page /pricing
# Created event 90 for page /about
# Created event 91 for page /pages
# Created event 92 for page /pricing
# Created event 93 for page /pages
# Created event 94 for page /pages
# Created event 95 for page /about
# Created event 96 for page /pricing
# Created event 97 for page /pages
# Created event 98 for page /about
# Created event 99 for page /about
# Created event 100 for page /contact
# Created event 101 for page /about
# Created event 102 for page /pages
# Created event 103 for page /contact
# Created event 104 for page /pages
# Created event 105 for page /pricing
# Created event 106 for page /pages
# Created event 107 for page /pages
# Created event 108 for page /contact
# Created event 109 for page /pricing
# Created event 110 for page /about
# Created event 111 for page /about
# Created event 112 for page /contact
# Created event 113 for page /pricing
# Created event 114 for page /about
# Created event 115 for page /pricing
# Created event 116 for page /pages
# Created event 117 for page /contact
# Created event 118 for page /about
# Created event 119 for page /about
# Created event 120 for page /about
# Created event 121 for page /contact
# Created event 122 for page /about
# Created event 123 for page /contact
# Created event 124 for page /pricing
# Created event 125 for page /pages
# Created event 126 for page /about
# Created event 127 for page /pages
# Created event 128 for page /pricing
# Created event 129 for page /contact
# Created event 130 for page /pages
# Created event 131 for page /contact
# Created event 132 for page /about
# Created event 133 for page /pricing
# Created event 134 for page /pages
# Created event 135 for page /about
# Created event 136 for page /contact
# Created event 137 for page /pages
# Created event 138 for page /about
# Created event 139 for page /pages
# Created event 140 for page /pricing
# Created event 141 for page /pages
# Created event 142 for page /pages
# Created event 143 for page /about
# Created event 144 for page /pages
# Created event 145 for page /pages
# Created event 146 for page /about
# Created event 147 for page /about
# Created event 148 for page /contact
# Created event 149 for page /about
# Created event 150 for page /pages
# Created event 151 for page /contact
# Created event 152 for page /about
# Created event 153 for page /contact
# Created event 154 for page /pages
# Created event 155 for page /pricing
# Created event 156 for page /about
# Created event 157 for page /about
# Created event 158 for page /pricing
# Created event 159 for page /pages
# Created event 160 for page /contact
# Created event 161 for page /pages
# Created event 162 for page /pricing
# Created event 163 for page /about
# Created event 164 for page /contact
# Created event 165 for page /contact
# Created event 166 for page /contact
# Created event 167 for page /pages
# Created event 168 for page /about
# Created event 169 for page /contact
# Created event 170 for page /contact
# Created event 171 for page /contact
# Created event 172 for page /contact
# Created event 173 for page /pricing
# Created event 174 for page /pages
# Created event 175 for page /about
# Created event 176 for page /contact
# Created event 177 for page /pages
# Created event 178 for page /about
# Created event 179 for page /pages
# Created event 180 for page /pages
# Created event 181 for page /contact
# Created event 182 for page /pages
# Created event 183 for page /pricing
# Created event 184 for page /pages
# Created event 185 for page /pricing
# Created event 186 for page /contact
# Created event 187 for page /about
# Created event 188 for page /pages
# Created event 189 for page /pricing
# Created event 190 for page /about
# Created event 191 for page /pages
# Created event 192 for page /contact
# Created event 193 for page /pricing
# Created event 194 for page /pages
# Created event 195 for page /contact
# Created event 196 for page /about
# Created event 197 for page /about
# Created event 198 for page /contact
# Created event 199 for page /contact
# Created event 200 for page /about
# Created event 201 for page /pricing
# Created event 202 for page /contact
# Created event 203 for page /contact
# Created event 204 for page /pages
# Created event 205 for page /pages
# Created event 206 for page /pricing
# Created event 207 for page /pricing
# Created event 208 for page /about
# Created event 209 for page /about
# Created event 210 for page /contact
# Created event 211 for page /contact
# Created event 212 for page /about
# Created event 213 for page /about
# Created event 214 for page /about
# Created event 215 for page /about
# Created event 216 for page /about
# Created event 217 for page /pricing
# Created event 218 for page /pages
# Created event 219 for page /contact
# Created event 220 for page /pricing
# Created event 221 for page /contact
# Created event 222 for page /contact
# Created event 223 for page /pricing
# Created event 224 for page /pricing
# Created event 225 for page /about
# Created event 226 for page /pricing
# Created event 227 for page /contact
# Created event 228 for page /contact
# Created event 229 for page /about
# Created event 230 for page /pricing
# Created event 231 for page /contact
# Created event 232 for page /about
# Created event 233 for page /pricing
# Created event 234 for page /pricing
# Created event 235 for page /contact
# Created event 236 for page /pricing
# Created event 237 for page /pricing
# Created event 238 for page /pages
# Created event 239 for page /about
# Created event 240 for page /about
# Created event 241 for page /contact
# Created event 242 for page /about
# Created event 243 for page /pages
# Created event 244 for page /about
# Created event 245 for page /contact
# Created event 246 for page /pricing
# Created event 247 for page /about
# Created event 248 for page /pricing
# Created event 249 for page /pricing
# Created event 250 for page /pages
# Created event 251 for page /contact
# Created event 252 for page /contact
# Created event 253 for page /about
# Created event 254 for page /contact
# Created event 255 for page /about
# Created event 256 for page /pages
# Created event 257 for page /about
# Created event 258 for page /pages
# Created event 259 for page /about
# Created event 260 for page /about
# Created event 261 for page /contact
# Created event 262 for page /contact
# Created event 263 for page /contact
# Created event 264 for page /contact
# Created event 265 for page /contact
# Created event 266 for page /pages
# Created event 267 for page /pricing
# Created event 268 for page /about
# Created event 269 for page /pages
# Created event 270 for page /contact
# Created event 271 for page /about
# Created event 272 for page /pricing
# Created event 273 for page /pricing
# Created event 274 for page /pricing
# Created event 275 for page /contact
# Created event 276 for page /pages
# Created event 277 for page /about
# Created event 278 for page /about
# Created event 279 for page /pricing
# Created event 280 for page /about
# Created event 281 for page /about
# Created event 282 for page /pages
# Created event 283 for page /pages
# Created event 284 for page /contact
# Created event 285 for page /about
# Created event 286 for page /pricing
# Created event 287 for page /pricing
# Created event 288 for page /about
# Created event 289 for page /pages
# Created event 290 for page /pricing
# Created event 291 for page /pricing
# Created event 292 for page /contact
# Created event 293 for page /about
# Created event 294 for page /contact
# Created event 295 for page /pages
# Created event 296 for page /pricing
# Created event 297 for page /pricing
# Created event 298 for page /contact
# Created event 299 for page /about
# Created event 300 for page /pages
# Created event 301 for page /about
# Created event 302 for page /contact
# Created event 303 for page /pricing
# Created event 304 for page /about
# Created event 305 for page /about
# Created event 306 for page /pages
# Created event 307 for page /contact
# Created event 308 for page /pages
# Created event 309 for page /pricing
# Created event 310 for page /contact
# Created event 311 for page /contact
# Created event 312 for page /about
# Created event 313 for page /pricing
# Created event 314 for page /about
# Created event 315 for page /pages
# Created event 316 for page /contact
# Created event 317 for page /about
# Created event 318 for page /about
# Created event 319 for page /pages
# Created event 320 for page /pages
# Created event 321 for page /pricing
# Created event 322 for page /pricing
# Created event 323 for page /about
# Created event 324 for page /pages
# Created event 325 for page /about
# Created event 326 for page /contact
# Created event 327 for page /pricing
# Created event 328 for page /pages
# Created event 329 for page /contact
# Created event 330 for page /about
# Created event 331 for page /contact
# Created event 332 for page /about
# Created event 333 for page /pages
# Created event 334 for page /pages
# Created event 335 for page /pricing
# Created event 336 for page /pages
# Created event 337 for page /pages
# Created event 338 for page /pages
# Created event 339 for page /about
# Created event 340 for page /contact
# Created event 341 for page /about
# Created event 342 for page /pages
# Created event 343 for page /pricing
# Created event 344 for page /pricing
# Created event 345 for page /about
# Created event 346 for page /about
# Created event 347 for page /contact
# Created event 348 for page /pricing
# Created event 349 for page /about
# Created event 350 for page /about
# Created event 351 for page /pricing
# Created event 352 for page /contact
# Created event 353 for page /about
# Created event 354 for page /contact
# Created event 355 for page /contact
# Created event 356 for page /pricing
# Created event 357 for page /pages
# Created event 358 for page /contact
# Created event 359 for page /pages
# Created event 360 for page /pricing
# Created event 361 for page /contact
# Created event 362 for page /about
# Created event 363 for page /contact
# Created event 364 for page /pricing
# Created event 365 for page /contact
# Created event 366 for page /about
# Created event 367 for page /about
# Created event 368 for page /about
# Created event 369 for page /pricing
# Created event 370 for page /about
# Created event 371 for page /about
# Created event 372 for page /about
# Created event 373 for page /pages
# Created event 374 for page /pages
# Created event 375 for page /pricing
# Created event 376 for page /about
# Created event 377 for page /pricing
# Created event 378 for page /pricing
# Created event 379 for page /about
# Created event 380 for page /pricing
# Created event 381 for page /contact
# Created event 382 for page /about
# Created event 383 for page /pricing
# Created event 384 for page /pages
# Created event 385 for page /about
# Created event 386 for page /contact
# Created event 387 for page /pricing
# Created event 388 for page /pages
# Created event 389 for page /pricing
# Created event 390 for page /pricing
# Created event 391 for page /pricing
# Created event 392 for page /pricing
# Created event 393 for page /pricing
# Created event 394 for page /pages
# Created event 395 for page /pricing
# Created event 396 for page /pricing
# Created event 397 for page /pages
# Created event 398 for page /pricing
# Created event 399 for page /pricing
# Created event 400 for page /contact
# Created event 401 for page /about
# Created event 402 for page /about
# Created event 403 for page /pages
# Created event 404 for page /pricing
# Created event 405 for page /contact
# Created event 406 for page /about
# Created event 407 for page /about
# Created event 408 for page /about
# Created event 409 for page /pricing
# Created event 410 for page /pages
# Created event 411 for page /pages
# Created event 412 for page /about
# Created event 413 for page /pricing
# Created event 414 for page /contact
# Created event 415 for page /contact
# Created event 416 for page /contact
# Created event 417 for page /contact
# Created event 418 for page /about
# Created event 419 for page /about
# Created event 420 for page /pages
# Created event 421 for page /contact
# Created event 422 for page /pages
# Created event 423 for page /contact
# Created event 424 for page /pages
# Created event 425 for page /contact
# Created event 426 for page /contact
# Created event 427 for page /about
# Created event 428 for page /pages
# Created event 429 for page /contact
# Created event 430 for page /contact
# Created event 431 for page /about
# Created event 432 for page /pages
# Created event 433 for page /contact
# Created event 434 for page /pricing
# Created event 435 for page /pages
# Created event 436 for page /pages
# Created event 437 for page /about
# Created event 438 for page /about
# Created event 439 for page /pages
# Created event 440 for page /contact
# Created event 441 for page /about
# Created event 442 for page /about
# Created event 443 for page /pages
# Created event 444 for page /pricing
# Created event 445 for page /pages
# Created event 446 for page /pages
# Created event 447 for page /contact
# Created event 448 for page /pages
# Created event 449 for page /contact
# Created event 450 for page /about
# Created event 451 for page /pages
# Created event 452 for page /about
# Created event 453 for page /contact
# Created event 454 for page /pages
# Created event 455 for page /contact
# Created event 456 for page /pages
# Created event 457 for page /contact
# Created event 458 for page /pricing
# Created event 459 for page /pricing
# Created event 460 for page /pages
# Created event 461 for page /about
# Created event 462 for page /contact
# Created event 463 for page /pricing
# Created event 464 for page /about
# Created event 465 for page /about
# Created event 466 for page /contact
# Created event 467 for page /pages
# Created event 468 for page /pricing
# Created event 469 for page /contact
# Created event 470 for page /pages
# Created event 471 for page /pages
# Created event 472 for page /pages
# Created event 473 for page /about
# Created event 474 for page /pages
# Created event 475 for page /pages
# Created event 476 for page /about
# Created event 477 for page /pricing
# Created event 478 for page /about
# Created event 479 for page /pricing
# Created event 480 for page /pages
# Created event 481 for page /contact
# Created event 482 for page /contact
# Created event 483 for page /about
# Created event 484 for page /pricing
# Created event 485 for page /contact
# Created event 486 for page /contact
# Created event 487 for page /pages
# Created event 488 for page /pricing
# Created event 489 for page /pages
# Created event 490 for page /about
# Created event 491 for page /pages
# Created event 492 for page /pricing
# Created event 493 for page /pricing
# Created event 494 for page /pricing
# Created event 495 for page /pages
# Created event 496 for page /about
# Created event 497 for page /about
# Created event 498 for page /pages
# Created event 499 for page /about
# Created event 500 for page /contact
# Created event 501 for page /contact
# Created event 502 for page /contact
# Created event 503 for page /about
# Created event 504 for page /about
# Created event 505 for page /contact
# Created event 506 for page /about
# Created event 507 for page /contact
# Created event 508 for page /contact
# Created event 509 for page /pages
# Created event 510 for page /pages
# Created event 511 for page /pricing
# Created event 512 for page /contact
# Created event 513 for page /pages
# Created event 514 for page /pages
# Created event 515 for page /pages
# Created event 516 for page /pages
# Created event 517 for page /about
# Created event 518 for page /contact
# Created event 519 for page /contact
# Created event 520 for page /about
# Created event 521 for page /pricing
# Created event 522 for page /about
# Created event 523 for page /about
# Created event 524 for page /about
# Created event 525 for page /about
# Created event 526 for page /contact
# Created event 527 for page /about
# Created event 528 for page /contact
# Created event 529 for page /contact
# Created event 530 for page /pages
# Created event 531 for page /contact
# Created event 532 for page /about
# Created event 533 for page /pages
# Created event 534 for page /contact
# Created event 535 for page /contact
# Created event 536 for page /contact
# Created event 537 for page /contact
# Created event 538 for page /pages
# Created event 539 for page /contact
# Created event 540 for page /about
# Created event 541 for page /about
# Created event 542 for page /pages
# Created event 543 for page /pages
# Created event 544 for page /contact
# Created event 545 for page /pricing
# Created event 546 for page /pages
# Created event 547 for page /pages
# Created event 548 for page /about
# Created event 549 for page /contact
# Created event 550 for page /pricing
# Created event 551 for page /contact
# Created event 552 for page /pricing
# Created event 553 for page /pages
# Created event 554 for page /contact
# Created event 555 for page /contact
# Created event 556 for page /about
# Created event 557 for page /about
# Created event 558 for page /contact
# Created event 559 for page /about
# Created event 560 for page /about
# Created event 561 for page /pricing
# Created event 562 for page /pages
# Created event 563 for page /pages
# Created event 564 for page /pricing
# Created event 565 for page /pages
# Created event 566 for page /pricing
# Created event 567 for page /about
# Created event 568 for page /pricing
# Created event 569 for page /pricing
# Created event 570 for page /pricing
# Created event 571 for page /contact
# Created event 572 for page /contact
# Created event 573 for page /pricing
# Created event 574 for page /contact
# Created event 575 for page /pricing
# Created event 576 for page /pricing
# Created event 577 for page /pages
# Created event 578 for page /pricing
# Created event 579 for page /pages
# Created event 580 for page /contact
# Created event 581 for page /pages
# Created event 582 for page /about
# Created event 583 for page /about
# Created event 584 for page /contact
# Created event 585 for page /about
# Created event 586 for page /about
# Created event 587 for page /about
# Created event 588 for page /pricing
# Created event 589 for page /pricing
# Created event 590 for page /pages
# Created event 591 for page /pages
# Created event 592 for page /about
# Created event 593 for page /pages
# Created event 594 for page /pricing
# Created event 595 for page /about
# Created event 596 for page /about
# Created event 597 for page /contact
# Created event 598 for page /about
# Created event 599 for page /about
# Created event 600 for page /pricing
# Created event 601 for page /pages
# Created event 602 for page /contact
# Created event 603 for page /pages
# Created event 604 for page /contact
# Created event 605 for page /pricing
# Created event 606 for page /pages
# Created event 607 for page /about
# Created event 608 for page /pages
# Created event 609 for page /pages
# Created event 610 for page /pages
# Created event 611 for page /about
# Created event 612 for page /contact
# Created event 613 for page /about
# Created event 614 for page /about
# Created event 615 for page /contact
# Created event 616 for page /pricing
# Created event 617 for page /about
# Created event 618 for page /contact
# Created event 619 for page /contact
# Created event 620 for page /pricing
# Created event 621 for page /pages
# Created event 622 for page /about
# Created event 623 for page /pricing
# Created event 624 for page /contact
# Created event 625 for page /contact
# Created event 626 for page /about
# Created event 627 for page /about
# Created event 628 for page /contact
# Created event 629 for page /pricing
# Created event 630 for page /pricing
# Created event 631 for page /pricing
# Created event 632 for page /pages
# Created event 633 for page /about
# Created event 634 for page /about
# Created event 635 for page /about
# Created event 636 for page /pages
# Created event 637 for page /contact
# Created event 638 for page /about
# Created event 639 for page /contact
# Created event 640 for page /pages
# Created event 641 for page /about
# Created event 642 for page /contact
# Created event 643 for page /pages
# Created event 644 for page /about
# Created event 645 for page /contact
# Created event 646 for page /contact
# Created event 647 for page /pages
# Created event 648 for page /contact
# Created event 649 for page /contact
# Created event 650 for page /about
# Created event 651 for page /about
# Created event 652 for page /pricing
# Created event 653 for page /pricing
# Created event 654 for page /pages
# Created event 655 for page /pages
# Created event 656 for page /contact
# Created event 657 for page /contact
# Created event 658 for page /pricing
# Created event 659 for page /about
# Created event 660 for page /contact
# Created event 661 for page /pages
# Created event 662 for page /contact
# Created event 663 for page /pages
# Created event 664 for page /contact
# Created event 665 for page /pricing
# Created event 666 for page /contact
# Created event 667 for page /pricing
# Created event 668 for page /pricing
# Created event 669 for page /contact
# Created event 670 for page /pricing
# Created event 671 for page /pricing
# Created event 672 for page /about
# Created event 673 for page /pricing
# Created event 674 for page /pricing
# Created event 675 for page /contact
# Created event 676 for page /about
# Created event 677 for page /about
# Created event 678 for page /pages
# Created event 679 for page /pages
# Created event 680 for page /pricing
# Created event 681 for page /about
# Created event 682 for page /contact
# Created event 683 for page /about
# Created event 684 for page /about
# Created event 685 for page /pricing
# Created event 686 for page /pages
# Created event 687 for page /about
# Created event 688 for page /pricing
# Created event 689 for page /pages
# Created event 690 for page /about
# Created event 691 for page /pricing
# Created event 692 for page /pricing
# Created event 693 for page /pricing
# Created event 694 for page /pages
# Created event 695 for page /contact
# Created event 696 for page /contact
# Created event 697 for page /pages
# Created event 698 for page /pricing
# Created event 699 for page /about
# Created event 700 for page /pages
# Created event 701 for page /contact
# Created event 702 for page /pricing
# Created event 703 for page /about
# Created event 704 for page /about
# Created event 705 for page /pages
# Created event 706 for page /contact
# Created event 707 for page /pages
# Created event 708 for page /contact
# Created event 709 for page /pages
# Created event 710 for page /about
# Created event 711 for page /pages
# Created event 712 for page /pages
# Created event 713 for page /contact
# Created event 714 for page /pages
# Created event 715 for page /pricing
# Created event 716 for page /contact
# Created event 717 for page /contact
# Created event 718 for page /pages
# Created event 719 for page /pages
# Created event 720 for page /about
# Created event 721 for page /pricing
# Created event 722 for page /about
# Created event 723 for page /contact
# Created event 724 for page /about
# Created event 725 for page /about
# Created event 726 for page /pages
# Created event 727 for page /about
# Created event 728 for page /pages
# Created event 729 for page /pricing
# Created event 730 for page /contact
# Created event 731 for page /about
# Created event 732 for page /pricing
# Created event 733 for page /pricing
# Created event 734 for page /contact
# Created event 735 for page /about
# Created event 736 for page /contact
# Created event 737 for page /pages
# Created event 738 for page /contact
# Created event 739 for page /contact
# Created event 740 for page /pricing
# Created event 741 for page /pricing
# Created event 742 for page /pricing
# Created event 743 for page /contact
# Created event 744 for page /contact
# Created event 745 for page /pricing
# Created event 746 for page /about
# Created event 747 for page /pricing
# Created event 748 for page /about
# Created event 749 for page /contact
# Created event 750 for page /about
# Created event 751 for page /pages
# Created event 752 for page /pricing
# Created event 753 for page /pages
# Created event 754 for page /pricing
# Created event 755 for page /pricing
# Created event 756 for page /contact
# Created event 757 for page /about
# Created event 758 for page /pricing
# Created event 759 for page /pages
# Created event 760 for page /about
# Created event 761 for page /pricing
# Created event 762 for page /about
# Created event 763 for page /pricing
# Created event 764 for page /pricing
# Created event 765 for page /pages
# Created event 766 for page /pages
# Created event 767 for page /pages
# Created event 768 for page /contact
# Created event 769 for page /pricing
# Created event 770 for page /pricing
# Created event 771 for page /about
# Created event 772 for page /contact
# Created event 773 for page /contact
# Created event 774 for page /pricing
# Created event 775 for page /pages
# Created event 776 for page /contact
# Created event 777 for page /contact
# Created event 778 for page /about
# Created event 779 for page /pages
# Created event 780 for page /pages
# Created event 781 for page /contact
# Created event 782 for page /contact
# Created event 783 for page /contact
# Created event 784 for page /about
# Created event 785 for page /pages
# Created event 786 for page /contact
# Created event 787 for page /pricing
# Created event 788 for page /about
# Created event 789 for page /pricing
# Created event 790 for page /pricing
# Created event 791 for page /pages
# Created event 792 for page /pages
# Created event 793 for page /pages
# Created event 794 for page /about
# Created event 795 for page /pricing
# Created event 796 for page /about
# Created event 797 for page /about
# Created event 798 for page /about
# Created event 799 for page /pricing
# Created event 800 for page /pricing
# Created event 801 for page /about
# Created event 802 for page /pages
# Created event 803 for page /about
# Created event 804 for page /about
# Created event 805 for page /pricing
# Created event 806 for page /pages
# Created event 807 for page /pages
# Created event 808 for page /pages
# Created event 809 for page /contact
# Created event 810 for page /contact
# Created event 811 for page /about
# Created event 812 for page /contact
# Created event 813 for page /pricing
# Created event 814 for page /pages
# Created event 815 for page /pricing
# Created event 816 for page /pricing
# Created event 817 for page /contact
# Created event 818 for page /contact
# Created event 819 for page /contact
# Created event 820 for page /about
# Created event 821 for page /pages
# Created event 822 for page /pages
# Created event 823 for page /contact
# Created event 824 for page /contact
# Created event 825 for page /about
# Created event 826 for page /pricing
# Created event 827 for page /pricing
# Created event 828 for page /pages
# Created event 829 for page /contact
# Created event 830 for page /pricing
# Created event 831 for page /contact
# Created event 832 for page /about
# Created event 833 for page /contact
# Created event 834 for page /contact
# Created event 835 for page /pages
# Created event 836 for page /pricing
# Created event 837 for page /about
# Created event 838 for page /contact
# Created event 839 for page /about
# Created event 840 for page /contact
# Created event 841 for page /pages
# Created event 842 for page /contact
# Created event 843 for page /pages
# Created event 844 for page /contact
# Created event 845 for page /pages
# Created event 846 for page /contact
# Created event 847 for page /contact
# Created event 848 for page /contact
# Created event 849 for page /about
# Created event 850 for page /pricing
# Created event 851 for page /pages
# Created event 852 for page /pages
# Created event 853 for page /pages
# Created event 854 for page /pricing
# Created event 855 for page /pricing
# Created event 856 for page /pages
# Created event 857 for page /pages
# Created event 858 for page /about
# Created event 859 for page /contact
# Created event 860 for page /contact
# Created event 861 for page /pricing
# Created event 862 for page /pricing
# Created event 863 for page /pricing
# Created event 864 for page /about
# Created event 865 for page /contact
# Created event 866 for page /pages
# Created event 867 for page /contact
# Created event 868 for page /contact
# Created event 869 for page /pricing
# Created event 870 for page /contact
# Created event 871 for page /contact
# Created event 872 for page /about
# Created event 873 for page /pricing
# Created event 874 for page /about
# Created event 875 for page /about
# Created event 876 for page /about
# Created event 877 for page /contact
# Created event 878 for page /contact
# Created event 879 for page /pages
# Created event 880 for page /about
# Created event 881 for page /pricing
# Created event 882 for page /pricing
# Created event 883 for page /contact
# Created event 884 for page /about
# Created event 885 for page /pages
# Created event 886 for page /pages
# Created event 887 for page /pricing
# Created event 888 for page /contact
# Created event 889 for page /contact
# Created event 890 for page /pricing
# Created event 891 for page /pages
# Created event 892 for page /pricing
# Created event 893 for page /pricing
# Created event 894 for page /pages
# Created event 895 for page /pages
# Created event 896 for page /contact
# Created event 897 for page /contact
# Created event 898 for page /about
# Created event 899 for page /pages
# Created event 900 for page /pricing
# Created event 901 for page /pricing
# Created event 902 for page /pages
# Created event 903 for page /pages
# Created event 904 for page /contact
# Created event 905 for page /pages
# Created event 906 for page /contact
# Created event 907 for page /pricing
# Created event 908 for page /about
# Created event 909 for page /contact
# Created event 910 for page /contact
# Created event 911 for page /pages
# Created event 912 for page /pages
# Created event 913 for page /pages
# Created event 914 for page /pages
# Created event 915 for page /contact
# Created event 916 for page /pricing
# Created event 917 for page /pricing
# Created event 918 for page /pricing
# Created event 919 for page /about
# Created event 920 for page /about
# Created event 921 for page /about
# Created event 922 for page /pages
# Created event 923 for page /pages
# Created event 924 for page /pages
# Created event 925 for page /contact
# Created event 926 for page /pricing
# Created event 927 for page /pricing
# Created event 928 for page /contact
# Created event 929 for page /pricing
# Created event 930 for page /pages
# Created event 931 for page /contact
# Created event 932 for page /pages
# Created event 933 for page /pricing
# Created event 934 for page /pricing
# Created event 935 for page /about
# Created event 936 for page /pages
# Created event 937 for page /contact
# Created event 938 for page /contact
# Created event 939 for page /pages
# Created event 940 for page /pages
# Created event 941 for page /about
# Created event 942 for page /pages
# Created event 943 for page /pages
# Created event 944 for page /contact
# Created event 945 for page /contact
# Created event 946 for page /pricing
# Created event 947 for page /contact
# Created event 948 for page /pages
# Created event 949 for page /pages
# Created event 950 for page /about
# Created event 951 for page /about
# Created event 952 for page /contact
# Created event 953 for page /contact
# Created event 954 for page /about
# Created event 955 for page /contact
# Created event 956 for page /contact
# Created event 957 for page /contact
# Created event 958 for page /about
# Created event 959 for page /pages
# Created event 960 for page /about
# Created event 961 for page /about
# Created event 962 for page /pricing
# Created event 963 for page /pricing
# Created event 964 for page /pages
# Created event 965 for page /about
# Created event 966 for page /pages
# Created event 967 for page /pricing
# Created event 968 for page /contact
# Created event 969 for page /contact
# Created event 970 for page /about
# Created event 971 for page /pricing
# Created event 972 for page /about
# Created event 973 for page /about
# Created event 974 for page /contact
# Created event 975 for page /pages
# Created event 976 for page /pages
# Created event 977 for page /about
# Created event 978 for page /pages
# Created event 979 for page /pages
# Created event 980 for page /pages
# Created event 981 for page /contact
# Created event 982 for page /pages
# Created event 983 for page /contact
# Created event 984 for page /pricing
# Created event 985 for page /pages
# Created event 986 for page /pricing
# Created event 987 for page /pages
# Created event 988 for page /pages
# Created event 989 for page /contact
# Created event 990 for page /pricing
# Created event 991 for page /pricing
# Created event 992 for page /about
# Created event 993 for page /about
# Created event 994 for page /contact
# Created event 995 for page /about
# Created event 996 for page /pricing
# Created event 997 for page /pages
# Created event 998 for page /pricing
# Created event 999 for page /about
# Created event 1000 for page /contact
